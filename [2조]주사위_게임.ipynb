# %% [markdown]
# <a href="https://colab.research.google.com/github/SeoSeo/dice_game_basic/blob/main/%5B2%EC%A1%B0%5D%EC%A3%BC%EC%82%AC%EC%9C%84_%EA%B2%8C%EC%9E%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2조 주사위 게임
# - 날짜 : 2022-12-30
# - 조원 : 신동원, 소인후, 이성철, 오세연, 장우진
# - 강사 : 김성진 강사님

# %% [markdown]
# ### 과제 규칙
#
# - 개발 방법론 방식 : Waterfall
#
# - 과제 내용 : 주사위 게임의 로직을 조별로 협의하여 프로젝트 명세서를 작성하고 랩터로 구현하여 제출.
#
# - 제출서류 : 프로젝트 명세서(자료 흐름도, 자료 명세서, 구조도, 흐름도(랩터 화면 캡쳐))
#
# - 이후에 파이썬으로 구현 예정.

# %% [markdown]
# ## Logic & Rule

# %% [markdown]
# ### Version 1
#
# - 아이디어 : 오징어 게임에서 기반하여 목숨을 건 데스 홀짝!
#
# 게임의 규칙
#
# 1. 플레이어는 총 2명 이며 보유 목숨은 1인당 3개.
# 2. 게임이 시작되면 매니저가 동전을 던져 결과(짝/홀)를 결정한다.(앞:0==짝,뒤:1==홀)
# 3. 플레이어들은 한 턴 당 1~6까지의 수를 가진 주사위 2개를 번갈아서 굴린다. (랜덤)
# 4. 각각의 무작위로 나온 주사위의 수를 각각 더하여 나온 결과를 짝(0)/홀(1)로 구분한다.
# 5. 매니저와 동일한 선택을 한 사람은 목숨을 잃지 않고(둘 다 동일한 선택이어도 마찬가지) 다른 선택을 하면 목숨을 잃는다.
# 6. 계속해서 게임을 해서 목숨을 잃은 사람은 탈락, 나머지 한 사람만이 살아남는다!

# %% [markdown]
# ### Version 2
# 아이디어 주로 제공 : 이성철, 장우진, 소인후
#
# **아이디어**
# - 주사위를 굴려서 홀/짝을 맞추면서 스테이지를 격파하자!
#
# **데이터(변수) 정의**
#
# - 플레이어 수 = 1
# - 매니저 수 = 1
# - 플레이어 목숨 수 = 3
# - 스테이지 수 = 10
# - 주사위의 수 = [1,2,3,4,5,6]
# - 플레이어의 결과 = 0(짝) or 1(홀)
# - 매니저의 결정 = 0(짝) or 1(홀)
#
# **게임의 규칙**
# 1. 게임 시작
#     1. 스테이지 10으로 설정 ⇒ 스테이지 1에서 시작. (한 판 끝날 때마다 스테이지 +1)
#     2. 플레이어 1의 목숨 3개로 시작
# 2. 매니저가 짝(0) 혹은 홀(1)을 결정함 → 랜덤 → “매니저의 결정”에 0 혹은 1 저장.
# 3. 플레이어가 주사위를 굴린다 → 랜덤함수로 1~6 골라서 output
# 4. 플레이어의 주사위 값이 짝인지 홀인지 확인 후 “플레이어의 결과”에 저장.
# 5. 매니저의 결정과 플레이어의 결과를 비교
#     1. 결과가 동일하면 목숨 수 변동 없음 (life - 0)
#     2. 결과가 동일하면 목숨 수 하나 깎임. (life - 1)
# 6. 스테이지 + 1
# 7. 다시 1로 가서 시작
# 8. 종료 조건 : 스테이지가 10 이거나 목숨이 0
#     1. 스테이지 10 이면 종료
#     2. 목숨이 0이면 종료
# 9. 반복문 종료 후 확인
#     1. 플레이어 목숨이 1이상 → 플레이어가 이김
#     2. 플레이어 목숨이 0이거나 스테이지 종료 전 목숨이 0이 됨 → 컴퓨터(==매니저) 우승

# %% [markdown]
# ## 구조도
# 구조도 - 소인후
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# ## 흐름도&자료흐름도(랩터 이용)

# %% [markdown]
# ![dice_game_ver2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Python 구현
# version 1 - 오세연

# %% [markdown]
# ### 수정된 & 추가된 내용 및 제약조건
# 1. 플레이어는 Enter를 누르기만 하면 random 메서드를 통해서 자동으로 결과를 얻는다.
# 2. 랩터와 다르게 매니저 역시 random으로 0 혹은 1의 값을 얻는다.

# %%
import random

# Variable 변수 선언
Player_num = 1
Manager_num = 1
Player_life = 3
Stage_num = 10
Stage = 1
dice = [1,2,3,4,5,6]
Player_result = 0
Manager_result = 0

# 게임 시작
print('='*20,'GAME START!!','='*20,'\n\n')
# game loop
while Stage <= Stage_num and Player_life > 0:
    print(f'{"-"*20}Now STAGE is : {Stage}!{"-"*20}')
    print('Manager will decide the result Even(0) or Odd(1).\n')
    Manager_result = random.randrange(0,2)
    input('Player will roll the dice! : (PRESS ENTER)\n')
    Player_result = random.randrange(1,7)
    print(f'Player got {Player_result}!')
    Player_result = 0 if Player_result % 2 == 0 else 1
    print('\n\nNow show the result!')
    print(f'Player Result is {"Even" if Player_result == 0 else "Odd"}')
    print(f'Manager Result is {"Even" if Manager_result == 0 else "Odd"}\n')
    print(f'This time player and Manager choose {"SAME" if Player_result == Manager_result else "DIFFERENT"}!\n')
    Player_life = (Player_life - 0) if Player_result == Manager_result else (Player_life - 1)
    print(f'Stage {Stage} is over. \nPlayer Life is now {Player_life}!\n')
    Stage += 1

# while 문이 종료된 원인 체크

# if Stage >= Stage_num:  # 스테이지 종료 전전
print('Player WIN!!!') if Player_life > 0 else print('Player LOSE!!')

# 전체 게임 종료
print('='*20,'GAME OVER','='*20)
# Out:
# ==================== GAME START!! ====================
#
#
# --------------------Now STAGE is : 1!--------------------
# Manager will decide the result Even(0) or Odd(1).
#
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 3!
#
#
# Now show the result!
# Player Result is Odd
# Manager Result is Even
#
# This time player and Manager choose DIFFERENT!
# Stage 1 is over.
# Player Life is now 2!
#
# --------------------Now STAGE is : 2!--------------------
# Manager will decide the result Even(0) or Odd(1).
#
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 2!
#
#
# Now show the result!
# Player Result is Even
# Manager Result is Even
#
# This time player and Manager choose SAME!
# Stage 2 is over.
# Player Life is now 2!
#
# --------------------Now STAGE is : 3!--------------------
# Manager will decide the result Even(0) or Odd(1).
#
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 5!
#
#
# Now show the result!
# Player Result is Odd
# Manager Result is Even
#
# This time player and Manager choose DIFFERENT!
# Stage 3 is over.
# Player Life is now 1!
#
# --------------------Now STAGE is : 4!--------------------
# Manager will decide the result Even(0) or Odd(1).
#
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 3!
#
#
# Now show the result!
# Player Result is Odd
# Manager Result is Even
#
# This time player and Manager choose DIFFERENT!
# Stage 4 is over.
# Player Life is now 0!
#
# Player LOSE!!
# ==================== GAME OVER ====================

# %%
# 함수로 묶은 버전
import random

def dicegame():
    # Variable
    Player_life = 3
    Stage_num = 10
    Stage = 1

    # Method
    print('='*20,'GAME START!!','='*20,'\n\n')
    while Stage <= Stage_num and Player_life > 0:
        print(f'{"-"*20}Now STAGE is : {Stage}!{"-"*20}')
        print('Manager will decide the result Even(0) or Odd(1).')
        Manager_result = random.randrange(0,2)
        input('Player will roll the dice! : (PRESS ENTER)\n')
        Player_result = random.randrange(1,7)
        print(f'Player got {Player_result}!')
        Player_result = 0 if Player_result % 2 == 0 else 1
        print('\n\nNow show the result!')
        print(f'Player Result is {"Even" if Player_result == 0 else "Odd"}')
        print(f'Manager Result is {"Even" if Manager_result == 0 else "Odd"}\n')
        print(f'This time player and Manager choose {"SAME" if Player_result == Manager_result else "DIFFERENT"}!\n')
        Player_life = (Player_life - 0) if Player_result == Manager_result else (Player_life - 1)
        print(f'Stage {Stage} is over. \nPlayer Life is now {Player_life}!\n')
        Stage += 1
    
    print('Player WIN!!!') if Player_life > 0 else print('Player LOSE!!')
    print('='*20,'GAME OVER!!','='*20)

# %%
# 실행
dicegame()
# Out:
# ==================== GAME START!! ====================
#
#
# --------------------Now STAGE is : 1!--------------------
# Manager will decide the result Even(0) or Odd(1).
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 1!
#
#
# Now show the result!
# Player Result is Odd
# Manager Result is Even
#
# This time player and Manager choose DIFFERENT!
#
# Stage 1 is over.
# Player Life is now 2!
#
# --------------------Now STAGE is : 2!--------------------
# Manager will decide the result Even(0) or Odd(1).
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 4!
#
#
# Now show the result!
# Player Result is Even
# Manager Result is Even
#
# This time player and Manager choose SAME!
#
# Stage 2 is over.
# Player Life is now 2!
#
# --------------------Now STAGE is : 3!--------------------
# Manager will decide the result Even(0) or Odd(1).
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 1!
#
#
# Now show the result!
# Player Result is Odd
# Manager Result is Even
#
# This time player and Manager choose DIFFERENT!
#
# Stage 3 is over.
# Player Life is now 1!
#
# --------------------Now STAGE is : 4!--------------------
# Manager will decide the result Even(0) or Odd(1).
# Player will roll the dice! : (PRESS ENTER)
#
# Player got 3!
#
#
# Now show the result!
# Player Result is Odd
# Manager Result is Even
#
# This time player and Manager choose DIFFERENT!
#
# Stage 4 is over.
# Player Life is now 0!
#
# Player LOSE!!
# ==================== GAME OVER!! ====================
